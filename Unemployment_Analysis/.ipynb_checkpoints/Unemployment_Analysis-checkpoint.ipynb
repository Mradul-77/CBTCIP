# %% [markdown]
# # Data description

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
from mpl_toolkits.mplot3d import Axes3D
from datetime import datetime
import datetime
import random

# %%
df = pd.read_excel(r'Unemployment in India.xlsx', engine='openpyxl')

# %%
df.shape
# Out:
# (754, 7)

# %%
df.head()
# Out:
#            Region        Date Frequency  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh  31-05-2019   Monthly                             3.65
# 1  Andhra Pradesh  30-06-2019   Monthly                             3.05
# 2  Andhra Pradesh  31-07-2019   Monthly                             3.75
# 3  Andhra Pradesh  31-08-2019   Monthly                             3.32
# 4  Andhra Pradesh  30-09-2019   Monthly                             5.17
#
#    Estimated Employed  Estimated Labour Participation Rate (%)   Area
# 0          11999139.0                                    43.24  Rural
# 1          11755881.0                                    42.05  Rural
# 2          12086707.0                                    43.50  Rural
# 3          12285693.0                                    43.97  Rural
# 4          12256762.0                                    44.68  Rural

# %%
df.tail()
# Out:
#           Region        Date Frequency  Estimated Unemployment Rate (%)  \
# 749  West Bengal  29-02-2020   Monthly                             7.55
# 750  West Bengal  31-03-2020   Monthly                             6.67
# 751  West Bengal  30-04-2020   Monthly                            15.63
# 752  West Bengal  31-05-2020   Monthly                            15.22
# 753  West Bengal  30-06-2020   Monthly                             9.86
#
#      Estimated Employed  Estimated Labour Participation Rate (%)   Area
# 749          10871168.0                                    44.09  Urban
# 750          10806105.0                                    43.34  Urban
# 751           9299466.0                                    41.20  Urban
# 752           9240903.0                                    40.67  Urban
# 753           9088931.0                                    37.57  Urban

# %%
df.describe()
# Out:
#        Estimated Unemployment Rate (%)  Estimated Employed  \
# count                       740.000000        7.400000e+02
# mean                         11.787946        7.204460e+06
# std                          10.721298        8.087988e+06
# min                           0.000000        4.942000e+04
# 25%                           4.657500        1.190404e+06
# 50%                           8.350000        4.744178e+06
# 75%                          15.887500        1.127549e+07
# max                          76.740000        4.577751e+07
#
#        Estimated Labour Participation Rate (%)
# count                               740.000000
# mean                                 42.630122
# std                                   8.111094
# min                                  13.330000
# 25%                                  38.062500
# 50%                                  41.160000
# 75%                                  45.505000
# max                                  72.570000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 754 entries, 0 to 753
# Data columns (total 7 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Region                                   740 non-null    object
#  1   Date                                     740 non-null    object
#  2   Frequency                                740 non-null    object
#  3   Estimated Unemployment Rate (%)          740 non-null    float64
#  4   Estimated Employed                       740 non-null    float64
#  5   Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                     740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 41.4+ KB

# %% [markdown]
# # Data Cleaning

# %%
# Checking for any null values

df.isnull().sum()
# Out:
# Region                                     14
# Date                                       14
# Frequency                                  14
# Estimated Unemployment Rate (%)            14
# Estimated Employed                         14
# Estimated Labour Participation Rate (%)    14
# Area                                       14
# dtype: int64

# %%
# Dropping all the rows with null/empty values

df.dropna(inplace=True)

# %%
# Checking the DataFrame now

df.isnull().sum()
# Out:
# Region                                     0
# Date                                       0
# Frequency                                  0
# Estimated Unemployment Rate (%)            0
# Estimated Employed                         0
# Estimated Labour Participation Rate (%)    0
# Area                                       0
# dtype: int64

# %%
df = df.drop(columns=['Frequency'])

# %%
df['Date']=pd.to_datetime(df['Date'], dayfirst=True)
df.head(2)
# Out:
#            Region       Date  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh 2019-05-31                             3.65
# 1  Andhra Pradesh 2019-06-30                             3.05
#
#    Estimated Employed  Estimated Labour Participation Rate (%)   Area
# 0          11999139.0                                    43.24  Rural
# 1          11755881.0                                    42.05  Rural

# %%
df['Year'] = df['Date'].dt.year
df['Month']=df['Date'].dt.month
df.head(14)
# Out:
#             Region       Date  Estimated Unemployment Rate (%)  \
# 0   Andhra Pradesh 2019-05-31                             3.65
# 1   Andhra Pradesh 2019-06-30                             3.05
# 2   Andhra Pradesh 2019-07-31                             3.75
# 3   Andhra Pradesh 2019-08-31                             3.32
# 4   Andhra Pradesh 2019-09-30                             5.17
# 5   Andhra Pradesh 2019-10-31                             3.52
# 6   Andhra Pradesh 2019-11-30                             4.12
# 7   Andhra Pradesh 2019-12-31                             4.38
# 8   Andhra Pradesh 2020-01-31                             4.84
# 9   Andhra Pradesh 2020-02-29                             5.91
# 10  Andhra Pradesh 2020-03-31                             4.06
# 11  Andhra Pradesh 2020-04-30                            16.29
# 12  Andhra Pradesh 2020-05-31                            14.46
# 13  Andhra Pradesh 2020-06-30                             0.85
#
# ...

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## Analysis according to Estimated Unemployment Rate (Rural)

# %% [markdown]
# ### 1. Andhra Pradesh

# %%
plt.figure(figsize=(15, 5))
AP_df=df[df['Area']=='Rural']
AP_df = AP_df[AP_df['Region'] == 'Andhra Pradesh']
AP_df = AP_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
def get_random_color():
    return (random.random(), random.random(), random.random())
colors = [get_random_color() for _ in range(len(AP_df))]
plt.bar(AP_df['YearMonth'], AP_df['Estimated Unemployment Rate (%)'], color=colors)
plt.xlabel('Year-Month')
plt.ylabel('Unemployment Rate')
plt.title('Unemployment Rate in Andhra Pradesh')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 2. Gujarat

# %%
plt.figure(figsize=(15, 5))
Gujrat_df=df[df['Area']=='Rural']
Gujrat_df = Gujrat_df[Gujrat_df['Region'] == 'Gujarat']
Gujrat_df = Gujrat_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
def get_random_color():
    return (random.random(), random.random(), random.random())
colors = [get_random_color() for _ in range(len(Gujrat_df))]
plt.bar(Gujrat_df['YearMonth'], Gujrat_df['Estimated Unemployment Rate (%)'], color=colors)
plt.xlabel('Year-Month')
plt.ylabel('Unemployment Rate')
plt.title('Unemployment Rate in Gujarat')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 3. Haryana

# %%
plt.figure(figsize=(15, 5))
H_df=df[df['Area']=='Rural']
H_df = H_df[H_df['Region'] == 'Haryana']
H_df = H_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
def get_random_color():
    return (random.random(), random.random(), random.random())
colors = [get_random_color() for _ in range(len(H_df))]
plt.bar(H_df['YearMonth'], H_df['Estimated Unemployment Rate (%)'], color=colors)
plt.xlabel('Year-Month')
plt.ylabel('Unemployment Rate')
plt.title('Unemployment Rate in Haryana')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 4. Himachal Pradesh

# %%
plt.figure(figsize=(15, 5))
HP_df=df[df['Area']=='Rural']
HP_df = HP_df[HP_df['Region'] == 'Himachal Pradesh']
HP_df = HP_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
def get_random_color():
    return (random.random(), random.random(), random.random())
colors = [get_random_color() for _ in range(len(HP_df))]
plt.bar(HP_df['YearMonth'], HP_df['Estimated Unemployment Rate (%)'], color=colors)
plt.xlabel('Year-Month')
plt.ylabel('Unemployment Rate')
plt.title('Unemployment Rate in Himachal Pradesh')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 5. Jammu & Kashmir

# %%
plt.figure(figsize=(15, 5))
JK_df=df[df['Area']=='Rural']
JK_df = JK_df[JK_df['Region'] == 'Jammu & Kashmir']
JK_df = JK_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
plt.plot(JK_df['YearMonth'], JK_df['Estimated Unemployment Rate (%)'], marker='o')
plt.xlabel('Year-Month')
plt.ylabel('Unemployment Rate')
plt.title('Unemployment Rate in Jammu & Kashmir')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 6. Jharkhand

# %%
plt.figure(figsize=(15, 5))
Jharkhand_df=df[df['Area']=='Rural']
Jharkhand_df = Jharkhand_df[Jharkhand_df['Region'] == 'Jharkhand']
Jharkhand_df = Jharkhand_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
plt.plot(Jharkhand_df['YearMonth'], Jharkhand_df['Estimated Unemployment Rate (%)'], marker='o', color='red')
plt.xlabel('Year-Month')
plt.ylabel('Unemployment Rate')
plt.title('Unemployment Rate in Jharkhand')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 7. Karnataka

# %%
plt.figure(figsize=(15, 5))
Karnataka_df=df[df['Area']=='Rural']
Karnataka_df = Karnataka_df[Karnataka_df['Region'] == 'Karnataka']
Karnataka_df = Karnataka_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
plt.plot(Karnataka_df['YearMonth'], Karnataka_df['Estimated Unemployment Rate (%)'], marker='o', color='green')
plt.xlabel('Year-Month')
plt.ylabel('Unemployment Rate')
plt.title('Unemployment Rate in Karnataka')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 8. Kerala

# %%
plt.figure(figsize=(15, 5))
Kerala_df=df[df['Area']=='Rural']
Kerala_df = Kerala_df[Kerala_df['Region'] == 'Kerala']
Kerala_df = Kerala_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
plt.plot(Kerala_df['YearMonth'], Kerala_df['Estimated Unemployment Rate (%)'], marker='o', color='purple')
plt.xlabel('Year-Month')
plt.ylabel('Unemployment Rate')
plt.title('Unemployment Rate in Kerala')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 9. Madhya Pradesh

# %%
plt.figure(figsize=(15, 5))
MP_df=df[df['Area']=='Rural']
MP_df = MP_df[MP_df['Region'] == 'Madhya Pradesh']
MP_df = MP_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
plt.fill_between(MP_df['YearMonth'], MP_df['Estimated Unemployment Rate (%)'], color="skyblue", alpha=0.4)
plt.plot(MP_df['YearMonth'], MP_df['Estimated Unemployment Rate (%)'], color="darkblue", alpha=0.6)
plt.xlabel('Year-Month')
plt.ylabel('Unemployment Rate')
plt.title('Unemployment Rate in Madhya Pradesh')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 10. Maharashtra

# %%
plt.figure(figsize=(15, 5))
Maharashtra_df=df[df['Area']=='Rural']
Maharashtra_df = Maharashtra_df[Maharashtra_df['Region'] == 'Maharashtra']
Maharashtra_df = Maharashtra_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
plt.fill_between(Maharashtra_df['YearMonth'], Maharashtra_df['Estimated Unemployment Rate (%)'], color="green", alpha=0.4)
plt.plot(Maharashtra_df['YearMonth'], Maharashtra_df['Estimated Unemployment Rate (%)'], color="darkgreen", alpha=0.6)
plt.xlabel('Year-Month')
plt.ylabel('Unemployment Rate')
plt.title('Unemployment Rate in Maharashtra')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 11. Meghalaya

# %%
plt.figure(figsize=(15, 5))
Meghalaya_df=df[df['Area']=='Rural']
Meghalaya_df = Meghalaya_df[Meghalaya_df['Region'] == 'Meghalaya']
Meghalaya_df = Meghalaya_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
plt.fill_between(Meghalaya_df['YearMonth'], Meghalaya_df['Estimated Unemployment Rate (%)'], color="red", alpha=0.4)
plt.plot(Meghalaya_df['YearMonth'], Meghalaya_df['Estimated Unemployment Rate (%)'], color="maroon", alpha=0.6)
plt.xlabel('Year-Month')
plt.ylabel('Unemployment Rate')
plt.title('Unemployment Rate in Meghalaya')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 12. Odisha

# %%
plt.figure(figsize=(15, 5))
Odisha_df=df[df['Area']=='Rural']
Odisha_df = Odisha_df[Odisha_df['Region'] == 'Odisha']
Odisha_df = Odisha_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
plt.scatter(Odisha_df['YearMonth'], Odisha_df['Estimated Unemployment Rate (%)'], color='blue')
plt.xlabel('Year-Month')
plt.ylabel('Unemployment Rate')
plt.title('Unemployment Rate in Odisha')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 13. Puducherry

# %%
plt.figure(figsize=(15, 5))
Puducherry_df=df[df['Area']=='Rural']
Puducherry_df = Puducherry_df[Puducherry_df['Region'] == 'Puducherry']
Puducherry_df = Puducherry_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
plt.scatter(Puducherry_df['YearMonth'], Puducherry_df['Estimated Unemployment Rate (%)'], color='red')
plt.xlabel('Year-Month')
plt.ylabel('Unemployment Rate')
plt.title('Unemployment Rate in Puducherry')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 14. Punjab

# %%
plt.figure(figsize=(15, 5))
Punjab_df=df[df['Area']=='Rural']
Punjab_df = Punjab_df[Punjab_df['Region'] == 'Punjab']
Punjab_df.loc[:,'Estimated Unemployment Rate (%)'] = pd.to_numeric(Punjab_df['Estimated Unemployment Rate (%)'], errors='coerce')
Punjab_df = Punjab_df.dropna(subset=['Estimated Unemployment Rate (%)'])
Punjab_df = Punjab_df.groupby(['Year', 'Month'], as_index=False)['Estimated Unemployment Rate (%)'].mean()
df_pivot = Punjab_df.pivot(index='Month', columns='Year', values='Estimated Unemployment Rate (%)')
sns.heatmap(df_pivot, annot=True, fmt=".1f", cmap="YlGnBu")
plt.xlabel('Year')
plt.ylabel('Month')
plt.title('Unemployment Rate in Punjab')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 15. Rajasthan

# %%
plt.figure(figsize=(15, 5))
Rajasthan_df=df[df['Area']=='Rural']
Rajasthan_df = Rajasthan_df[Rajasthan_df['Region'] == 'Rajasthan']
Rajasthan_df.loc[:,'Estimated Unemployment Rate (%)'] = pd.to_numeric(Rajasthan_df['Estimated Unemployment Rate (%)'], errors='coerce')
Rajasthan_df = Rajasthan_df.dropna(subset=['Estimated Unemployment Rate (%)'])
Rajasthan_df = Rajasthan_df.groupby(['Year', 'Month'], as_index=False)['Estimated Unemployment Rate (%)'].mean()
df_pivot = Rajasthan_df.pivot(index='Month', columns='Year', values='Estimated Unemployment Rate (%)')
sns.heatmap(df_pivot, annot=True, fmt=".1f", cmap="YlGnBu")
plt.xlabel('Year')
plt.ylabel('Month')
plt.title('Unemployment Rate in Rajasthan')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 16. Sikkim

# %%
plt.figure(figsize=(15, 5))
Sikkim_df=df[df['Area']=='Rural']
Sikkim_df = Sikkim_df[Sikkim_df['Region'] == 'Sikkim']
Sikkim_df.loc[:,'Estimated Unemployment Rate (%)'] = pd.to_numeric(Sikkim_df['Estimated Unemployment Rate (%)'], errors='coerce')
Sikkim_df = Sikkim_df.dropna(subset=['Estimated Unemployment Rate (%)'])
Sikkim_df = Sikkim_df.groupby(['Year', 'Month'], as_index=False)['Estimated Unemployment Rate (%)'].mean()
df_pivot = Sikkim_df.pivot(index='Month', columns='Year', values='Estimated Unemployment Rate (%)')
sns.heatmap(df_pivot, annot=True, fmt=".1f", cmap="YlGnBu")
plt.xlabel('Year')
plt.ylabel('Month')
plt.title('Unemployment Rate in Sikkim')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 17. Tamil Nadu

# %%
plt.figure(figsize=(15, 5))
TM_df=df[df['Area']=='Rural']
TM_df = TM_df[TM_df['Region'] == 'Tamil Nadu']
TM_df.loc[:,'Estimated Unemployment Rate (%)'] = pd.to_numeric(TM_df['Estimated Unemployment Rate (%)'], errors='coerce')
TM_df = TM_df.dropna(subset=['Estimated Unemployment Rate (%)'])
TM_df = TM_df.groupby(['Year', 'Month'], as_index=False)['Estimated Unemployment Rate (%)'].mean()
df_pivot = TM_df.pivot(index='Month', columns='Year', values='Estimated Unemployment Rate (%)')
sns.heatmap(df_pivot, annot=True, fmt=".1f", cmap="YlGnBu")
plt.xlabel('Year')
plt.ylabel('Month')
plt.title('Unemployment Rate in Tamil Nadu')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 18. Telangana

# %%
plt.figure(figsize=(15, 5))
Telangana_df=df[df['Area']=='Rural']
Telangana_df = Telangana_df[Telangana_df['Region'] == 'Telangana']
Telangana_df = Telangana_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
plt.plot(Telangana_df['YearMonth'], Telangana_df['Estimated Unemployment Rate (%)'], marker='o')
plt.xlabel('Year')
plt.ylabel('Month')
plt.title('Unemployment Rate in Telangana')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 19. Tripura

# %%
plt.figure(figsize=(15, 5))
Tripura_df=df[df['Area']=='Rural']
Tripura_df = Tripura_df[Tripura_df['Region'] == 'Tripura']
Tripura_df = Tripura_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
def get_random_color():
    return (random.random(), random.random(), random.random())
colors = [get_random_color() for _ in range(len(Tripura_df))]
plt.bar(Tripura_df['YearMonth'], Tripura_df['Estimated Unemployment Rate (%)'], color=colors)
plt.xlabel('Year-Month')
plt.ylabel('Unemployment Rate')
plt.title('Unemployment Rate in Tripura')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 20. Uttar Pradesh

# %%
plt.figure(figsize=(15, 5))
UP_df=df[df['Area']=='Rural']
UP_df = UP_df[UP_df['Region'] == 'Uttar Pradesh']
UP_df = UP_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
def get_random_color():
    return (random.random(), random.random(), random.random())
colors = [get_random_color() for _ in range(len(UP_df))]
plt.bar(UP_df['YearMonth'], UP_df['Estimated Unemployment Rate (%)'], color=colors)
plt.xlabel('Year-Month')
plt.ylabel('Unemployment Rate')
plt.title('Unemployment Rate in Uttar Pradesh')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 21. Uttarakhand

# %%
plt.figure(figsize=(15, 5))
Uttarakhand_df=df[df['Area']=='Rural']
Uttarakhand_df = Uttarakhand_df[Uttarakhand_df['Region'] == 'Uttarakhand']
Uttarakhand_df = Uttarakhand_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
plt.plot(Uttarakhand_df['YearMonth'], Uttarakhand_df['Estimated Unemployment Rate (%)'], marker='o', color='brown')
plt.xlabel('Year-Month')
plt.ylabel('Unemployment Rate')
plt.title('Unemployment Rate in Uttarakhand')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 22. West Bengal

# %%
plt.figure(figsize=(15, 5))
WB_df=df[df['Area']=='Rural']
WB_df = WB_df[WB_df['Region'] == 'West Bengal']
WB_df = WB_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
plt.fill_between(WB_df['YearMonth'], WB_df['Estimated Unemployment Rate (%)'], color="cyan", alpha=0.4)
plt.plot(WB_df['YearMonth'], WB_df['Estimated Unemployment Rate (%)'], color="blue", alpha=0.6)
plt.xlabel('Year-Month')
plt.ylabel('Unemployment Rate')
plt.title('Unemployment Rate in West Bengal')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Analysis according to Estimated Employed (Urban)

# %% [markdown]
# ### 1. Andhra Pradesh

# %%
plt.figure(figsize=(15, 5))
AP_df=df[df['Area']=='Urban']
AP_df = AP_df[AP_df['Region'] == 'Andhra Pradesh']
AP_df = AP_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
def get_random_color():
    return (random.random(), random.random(), random.random())
colors = [get_random_color() for _ in range(len(AP_df))]
plt.bar(AP_df['YearMonth'], AP_df['Estimated Employed'], color=colors)
plt.xlabel('Year-Month')
plt.ylabel('Estimated Employed')
plt.title('Estimated Employed in Andhra Pradesh')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 2. Gujarat

# %%
plt.figure(figsize=(15, 5))
Gujrat_df=df[df['Area']=='Urban']
Gujrat_df = Gujrat_df[Gujrat_df['Region'] == 'Gujarat']
Gujrat_df = Gujrat_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
def get_random_color():
    return (random.random(), random.random(), random.random())
colors = [get_random_color() for _ in range(len(Gujrat_df))]
plt.bar(Gujrat_df['YearMonth'], Gujrat_df['Estimated Employed'], color=colors)
plt.xlabel('Year-Month')
plt.ylabel('Estimated Employed')
plt.title('Estimated Employed in Gujarat')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 3. Haryana

# %%
plt.figure(figsize=(15, 5))
H_df=df[df['Area']=='Urban']
H_df = H_df[H_df['Region'] == 'Haryana']
H_df = H_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
def get_random_color():
    return (random.random(), random.random(), random.random())
colors = [get_random_color() for _ in range(len(H_df))]
plt.bar(H_df['YearMonth'], H_df['Estimated Employed'], color=colors)
plt.xlabel('Year-Month')
plt.ylabel('Estimated Employed')
plt.title('Estimated Employed in Haryana')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 4. Himachal Pradesh

# %%
plt.figure(figsize=(15, 5))
HP_df=df[df['Area']=='Urban']
HP_df = HP_df[HP_df['Region'] == 'Himachal Pradesh']
HP_df = HP_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
def get_random_color():
    return (random.random(), random.random(), random.random())
colors = [get_random_color() for _ in range(len(HP_df))]
plt.bar(HP_df['YearMonth'], HP_df['Estimated Employed'], color=colors)
plt.xlabel('Year-Month')
plt.ylabel('Estimated Employed')
plt.title('Estimated Employed in Himachal Pradesh')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 5. Jammu & Kashmir

# %%
plt.figure(figsize=(15, 5))
JK_df=df[df['Area']=='Urban']
JK_df = JK_df[JK_df['Region'] == 'Jammu & Kashmir']
JK_df = JK_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
plt.plot(JK_df['YearMonth'], JK_df['Estimated Employed'], marker='o')
plt.xlabel('Year-Month')
plt.ylabel('Estimated Employed')
plt.title('Estimated Employed in Jammu & Kashmir')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 6. Jharkhand

# %%
plt.figure(figsize=(15, 5))
Jharkhand_df=df[df['Area']=='Urban']
Jharkhand_df = Jharkhand_df[Jharkhand_df['Region'] == 'Jharkhand']
Jharkhand_df = Jharkhand_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
plt.plot(Jharkhand_df['YearMonth'], Jharkhand_df['Estimated Employed'], marker='o', color='red')
plt.xlabel('Year-Month')
plt.ylabel('Estimated Employed')
plt.title('Estimated Employed in Jharkhand')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 7. Karnataka

# %%
plt.figure(figsize=(15, 5))
Karnataka_df=df[df['Area']=='Urban']
Karnataka_df = Karnataka_df[Karnataka_df['Region'] == 'Karnataka']
Karnataka_df = Karnataka_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
plt.plot(Karnataka_df['YearMonth'], Karnataka_df['Estimated Employed'], marker='o', color='green')
plt.xlabel('Year-Month')
plt.ylabel('Estimated Employed')
plt.title('Estimated Employed in Karnataka')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 8. Kerala

# %%
plt.figure(figsize=(15, 5))
Kerala_df=df[df['Area']=='Urban']
Kerala_df = Kerala_df[Kerala_df['Region'] == 'Kerala']
Kerala_df = Kerala_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
plt.plot(Kerala_df['YearMonth'], Kerala_df['Estimated Employed'], marker='o', color='purple')
plt.xlabel('Year-Month')
plt.ylabel('Estimated Employed')
plt.title('Estimated Employed in Kerala')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 9. Madhya Pradesh

# %%
plt.figure(figsize=(15, 5))
MP_df=df[df['Area']=='Urban']
MP_df = MP_df[MP_df['Region'] == 'Madhya Pradesh']
MP_df = MP_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
plt.fill_between(MP_df['YearMonth'], MP_df['Estimated Employed'], color="skyblue", alpha=0.4)
plt.plot(MP_df['YearMonth'], MP_df['Estimated Employed'], color="darkblue", alpha=0.6)
plt.xlabel('Year-Month')
plt.ylabel('Estimated Employed')
plt.title('Estimated Employed in Madhya Pradesh')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 10. Maharashtra

# %%
plt.figure(figsize=(15, 5))
Maharashtra_df=df[df['Area']=='Urban']
Maharashtra_df = Maharashtra_df[Maharashtra_df['Region'] == 'Maharashtra']
Maharashtra_df = Maharashtra_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
plt.fill_between(Maharashtra_df['YearMonth'], Maharashtra_df['Estimated Employed'], color="green", alpha=0.4)
plt.plot(Maharashtra_df['YearMonth'], Maharashtra_df['Estimated Employed'], color="darkgreen", alpha=0.6)
plt.xlabel('Year-Month')
plt.ylabel('Estimated Employed')
plt.title('Estimated Employed in Maharashtra')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 11. Meghalaya

# %%
plt.figure(figsize=(15, 5))
Meghalaya_df=df[df['Area']=='Urban']
Meghalaya_df = Meghalaya_df[Meghalaya_df['Region'] == 'Meghalaya']
Meghalaya_df = Meghalaya_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
plt.fill_between(Meghalaya_df['YearMonth'], Meghalaya_df['Estimated Employed'], color="red", alpha=0.4)
plt.plot(Meghalaya_df['YearMonth'], Meghalaya_df['Estimated Employed'], color="maroon", alpha=0.6)
plt.xlabel('Year-Month')
plt.ylabel('Estimated Employed')
plt.title('Estimated Employed in Meghalaya')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 12. Odisha

# %%
plt.figure(figsize=(15, 5))
Odisha_df=df[df['Area']=='Urban']
Odisha_df = Odisha_df[Odisha_df['Region'] == 'Odisha']
Odisha_df = Odisha_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
plt.scatter(Odisha_df['YearMonth'], Odisha_df['Estimated Employed'], color='blue')
plt.xlabel('Year-Month')
plt.ylabel('Estimated Employed')
plt.title('Estimated Employed in Odisha')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 13. Puducherry

# %%
plt.figure(figsize=(15, 5))
Puducherry_df=df[df['Area']=='Urban']
Puducherry_df = Puducherry_df[Puducherry_df['Region'] == 'Puducherry']
Puducherry_df = Puducherry_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
plt.scatter(Puducherry_df['YearMonth'], Puducherry_df['Estimated Employed'], color='red')
plt.xlabel('Year-Month')
plt.ylabel('Estimated Employed')
plt.title('Estimated Employed in Puducherry')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 14. Punjab

# %%
plt.figure(figsize=(15, 5))
Punjab_df=df[df['Area']=='Urban']
Punjab_df = Punjab_df[Punjab_df['Region'] == 'Punjab']
Punjab_df.loc[:,'Estimated Employed'] = pd.to_numeric(Punjab_df['Estimated Employed'], errors='coerce')
Punjab_df = Punjab_df.dropna(subset=['Estimated Employed'])
Punjab_df = Punjab_df.groupby(['Year', 'Month'], as_index=False)['Estimated Employed'].mean()
df_pivot = Punjab_df.pivot(index='Month', columns='Year', values='Estimated Employed')
sns.heatmap(df_pivot, annot=True, fmt=".1f", cmap="YlGnBu")
plt.xlabel('Year')
plt.ylabel('Month')
plt.title('Estimated Employed in Punjab')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 15. Rajasthan

# %%
plt.figure(figsize=(15, 5))
Rajasthan_df=df[df['Area']=='Urban']
Rajasthan_df = Rajasthan_df[Rajasthan_df['Region'] == 'Rajasthan']
Rajasthan_df.loc[:,'Estimated Employed'] = pd.to_numeric(Rajasthan_df['Estimated Employed'], errors='coerce')
Rajasthan_df = Rajasthan_df.dropna(subset=['Estimated Employed'])
Rajasthan_df = Rajasthan_df.groupby(['Year', 'Month'], as_index=False)['Estimated Employed'].mean()
df_pivot = Rajasthan_df.pivot(index='Month', columns='Year', values='Estimated Employed')
sns.heatmap(df_pivot, annot=True, fmt=".1f", cmap="YlGnBu")
plt.xlabel('Year')
plt.ylabel('Month')
plt.title('Estimated Employed in Rajasthan')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 16. Sikkim

# %%
plt.figure(figsize=(15, 5))
Sikkim_df=df[df['Area']=='Urban']
Sikkim_df = Sikkim_df[Sikkim_df['Region'] == 'Sikkim']
Sikkim_df.loc[:,'Estimated Employed'] = pd.to_numeric(Sikkim_df['Estimated Employed'], errors='coerce')
Sikkim_df = Sikkim_df.dropna(subset=['Estimated Employed'])
Sikkim_df = Sikkim_df.groupby(['Year', 'Month'], as_index=False)['Estimated Employed'].mean()
df_pivot = Sikkim_df.pivot(index='Month', columns='Year', values='Estimated Employed')
sns.heatmap(df_pivot, annot=True, fmt=".1f", cmap="YlGnBu")
plt.xlabel('Year')
plt.ylabel('Month')
plt.title('Estimated Employed in Sikkim')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 17. Tamil Nadu

# %%
plt.figure(figsize=(15, 5))
TM_df=df[df['Area']=='Urban']
TM_df = TM_df[TM_df['Region'] == 'Tamil Nadu']
TM_df.loc[:,'Estimated Employed'] = pd.to_numeric(TM_df['Estimated Employed'], errors='coerce')
TM_df = TM_df.dropna(subset=['Estimated Employed'])
TM_df = TM_df.groupby(['Year', 'Month'], as_index=False)['Estimated Employed'].mean()
df_pivot = TM_df.pivot(index='Month', columns='Year', values='Estimated Employed')
sns.heatmap(df_pivot, annot=True, fmt=".1f", cmap="YlGnBu")
plt.xlabel('Year')
plt.ylabel('Month')
plt.title('Estimated Employed in Tamil Nadu')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 18. Telangana

# %%
plt.figure(figsize=(15, 5))
Telangana_df=df[df['Area']=='Urban']
Telangana_df = Telangana_df[Telangana_df['Region'] == 'Telangana']
Telangana_df = Telangana_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
plt.plot(Telangana_df['YearMonth'], Telangana_df['Estimated Employed'], marker='o')
plt.xlabel('Year')
plt.ylabel('Month')
plt.title('Estimated Employed in Telangana')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 19. Tripura

# %%
plt.figure(figsize=(15, 5))
Tripura_df=df[df['Area']=='Urban']
Tripura_df = Tripura_df[Tripura_df['Region'] == 'Tripura']
Tripura_df = Tripura_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
def get_random_color():
    return (random.random(), random.random(), random.random())
colors = [get_random_color() for _ in range(len(Tripura_df))]
plt.bar(Tripura_df['YearMonth'], Tripura_df['Estimated Employed'], color=colors)
plt.xlabel('Year-Month')
plt.ylabel('Estimated Employed')
plt.title('Estimated Employed in Tripura')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 20. Uttar Pradesh

# %%
plt.figure(figsize=(15, 5))
UP_df=df[df['Area']=='Urban']
UP_df = UP_df[UP_df['Region'] == 'Uttar Pradesh']
UP_df = UP_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
def get_random_color():
    return (random.random(), random.random(), random.random())
colors = [get_random_color() for _ in range(len(UP_df))]
plt.bar(UP_df['YearMonth'], UP_df['Estimated Employed'], color=colors)
plt.xlabel('Year-Month')
plt.ylabel('Estimated Employed')
plt.title('Estimated Employed in Uttar Pradesh')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 21. Uttarakhand

# %%
plt.figure(figsize=(15, 5))
Uttarakhand_df=df[df['Area']=='Urban']
Uttarakhand_df = Uttarakhand_df[Uttarakhand_df['Region'] == 'Uttarakhand']
Uttarakhand_df = Uttarakhand_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
plt.plot(Uttarakhand_df['YearMonth'], Uttarakhand_df['Estimated Employed'], marker='o', color='brown')
plt.xlabel('Year-Month')
plt.ylabel('Estimated Employed')
plt.title('Estimated Employed in Uttarakhand')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 22. West Bengal

# %%
plt.figure(figsize=(15, 5))
WB_df=df[df['Area']=='Urban']
WB_df = WB_df[WB_df['Region'] == 'West Bengal']
WB_df = WB_df.assign(YearMonth=lambda x: x['Year'].astype(str) + '-' + x['Month'].astype(str))
plt.fill_between(WB_df['YearMonth'], WB_df['Estimated Employed'], color="cyan", alpha=0.4)
plt.plot(WB_df['YearMonth'], WB_df['Estimated Employed'], color="blue", alpha=0.6)
plt.xlabel('Year-Month')
plt.ylabel('Estimated Employed')
plt.title('Estimated Employed in West Bengal')
plt.tight_layout()
plt.grid(True)
plt.show()
